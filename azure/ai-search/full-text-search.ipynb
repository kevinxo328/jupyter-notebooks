# %%
# %pip install azure-search-documents
# %pip install azure-core
# %pip install pydantic-settings

# %%
from pydantic_settings import BaseSettings

class Env(BaseSettings):
    SEARCH_API_KEY:str
    SEARCH_INDEX:str
    SEARCH_SERVICE_NAME:str
    class Config:
        env_file = "full-text-search.env"
        
env = Env()

# %% [markdown]
# ## Example of a full text query request
# - https://learn.microsoft.com/en-us/azure/search/search-query-create?tabs=portal-text-query#example-of-a-full-text-query-request

# %%
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient

service_endpoint = 'https://'+ env.SEARCH_SERVICE_NAME + '.search.windows.net'
index_name = env.SEARCH_INDEX
key = env.SEARCH_API_KEY

search_client = SearchClient(service_endpoint, index_name, AzureKeyCredential(key))
results = search_client.search(search_text="腎臟", query_type="full", search_mode="all")

for result in results:
    print(result['content'])
# Out:
# 末期腎臟病 ，我應該選擇哪一種治療方式 ?
# 當醫療人員告訴我，可能要開始考慮洗腎或換腎
# Q：我的腎臟功能有可能恢復成比現在還好的狀態嗎？
# Q：洗腎要洗一輩子嗎？
# A：急性腎衰竭的病人腎功能較有可能恢復；慢性腎臟病所引起的尿毒
# 症，就無法恢復，需要長時間洗腎。但若能成功接受腎臟移植，就可
# 脫離洗腎 。
# 參考資料
# 一、衛生福利部國民健康署 ，就醫提問單 [慢性腎臟
# 病-關於洗腎和換腎 ]。
# B. 關於換腎，我想了解：
# Q：換腎之後，新的腎臟可能可以用多久？如果不能用了，會怎麼樣？
# A：因人而異 。如果不能用 ，仍可以 保有第 2次移植機會或 改用透析治療。
# 病-關於洗腎和換腎 ]。
# 二、影片來源 衛生福利部國民健康署， 醫病共享決
# 策影片。
#  編印單位 : 腎臟內科
# 編印日期 :  109年 05月 06日第 1 版
# A：如果是急性腎衰竭是可以的；若是慢性腎 臟病就要依靠低蛋白飲食控
# 制來降低尿毒素，但無法恢復到正常 。
# Q：有可能晚一點洗腎或不洗腎嗎？如果不洗腎，會怎麼樣？
# 情境模擬影片： 面對末期腎臟病，我應該選擇哪一種治療方式
# 歡迎使用手機掃瞄 QR Code 觀看影片
# 國語版  台語版  客語版
# A：洗腎是看個人腎功能抽血指數及症狀做決定；若指數太高未洗腎可能
# 會有生命危險 。
# Q：洗腎可以改善我不舒服的症狀嗎？
# A：如果是因尿毒太高引起的不舒服是可慢慢改善的 。
# 脫離洗腎 。
# Q：決定治療方式後，就會馬上進行嗎？或是我可以決定什麼時候進行？
# A：洗腎是看個人的腎功能抽血指數及症狀做決定 是否馬上進行 。
# Q：如果不洗腎，有其他方式可以讓我感覺好一點嗎？需要符合什麼條
# 件？
# A：有時可以先用藥物來緩解毒素高帶來的 症狀，但有一定的 限度；若年
# 齡偏大或 有其他器官衰竭可以跟醫師商量是否可安寧治療 。
# A. 關於洗腎（腹膜透析或血液透析），我想了解：
# Q：選了一種洗腎方式之後，以後就不能再改另一種嗎？
# A：可與醫師討論後做更改 。
# Q：我可以同時選擇腹膜透析和血液透析嗎？
# A：除非有特殊情形 ，依目前健保制度是二者擇一 。
# Q：什麼樣的環境才能洗腹膜透析？
# A：清潔密閉空間 。
# Q：我能不能看看實際透析如何操作？有圖片或影片可以參考嗎？
# A：有圖片或影片 可以看。
# Q：洗腎會影響到旅遊或出差嗎？
# A：可以事先安排聯絡透析中心 。
# Q：洗腎會影響到生育能力嗎？
# Q：洗腎會影響到生育能力嗎？
# A：腎功能不好才 會影響生育能力 ，特別是女性排 卵功能會退化，生育能
# 力會下降 。男性病人的生育能力則影響不大。
# B. 關於換腎，我想了解：
# Q：如果我的家人捐腎給我，以後他洗腎的機率會不會變高？
# A：移植前醫師會對捐贈 者做詳細的評估 ，確認捐贈者風險低於 1%，才會
# 同意移植 。
# 我已經決定或準備決定治療方式，我想知道更多：
# Q：以後去看其他門診或急診，有什麼需要先告知醫療人員嗎？
# A：要告知是否接受了血液透析或腹膜透析。 若有做透析 瘻管，需提醒醫
# 療人員。 有瘻管的肢體勿做治療。 開立的藥物劑量也要酌予減 少。
# Q：有什麼是需要家人幫助，我可能要跟家人討論的？
# A：腹膜透析是在家自行操作，身體若不舒服無法自行換液， 就需家屬協
# 助。血液透析後，可能會有血壓不穩、頭暈、抽筋可能需要陪同。
# Q：我的狀況可以申請哪些補助？怎麼申請？
# A：重大傷病卡、 身心障礙手冊 殘障手冊、 勞農保的殘廢給付、 如有其它
# 保險也可辦理請領給付 ，詳情可找投保單位或社工室 。
# Q：我有交通的問題，有沒有車可以接送？如果有的話，費用怎麼算？
# A：可申請復康巴士。 一般費率：以新北市政府核定 為準。
# 修訂日期 :  111年10 月 24日第 2 版
# 全院編碼 : 亞東醫院出版品 SH433
#
# 宗    旨: 持續提升醫療品質
#           善盡社會醫療責任
# 願    景: 成為民眾首選的醫學中心  亞東紀念醫院   祝您健康
